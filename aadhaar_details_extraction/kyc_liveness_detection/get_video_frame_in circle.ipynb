# %%
import face_recognition
import cv2
import imutils

# %%
def draw_rectangle(frame):

    # Draw a rectangle in the middle of the screen
    rectangle_width = 320
    rectangle_height = 320
    rect_start_x = (frame.shape[1] - rectangle_width) // 2
    rect_start_y = (frame.shape[0] - rectangle_height) // 2
    rect_end_x = rect_start_x + rectangle_width
    rect_end_y = rect_start_y + rectangle_height
    cv2.rectangle(frame, (rect_start_x, rect_start_y), (rect_end_x, rect_end_y), (0, 255, 0), 2)

    return frame

# %%
def get_face_from_image(input_image):

    face_locations = face_recognition.face_locations(input_image)

    if len(face_locations) > 1 :

        print("Multiple faces detected")
        return None

    for face_location in face_locations:

        # Print the location of each face in this image
        top, right, bottom, left = face_location
        print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

        # You can access the actual face itself like this:
        # input_image = input_image[top:bottom, left:right]

        return [top, right, bottom, left]

# %%
# Open a connection to the webcam (you may need to change the argument based on your webcam index)
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # resize the frame
    frame = imutils.resize(frame, width=640, height=640)


    # draw rectangle for region of interest
    frame = draw_rectangle(frame)    

    # get face coordinates if there

    
    detection_of_face = get_face_from_image(frame)
    print(detection_of_face)

    if detection_of_face is not None:

        frame = cv2.rectangle(frame, (detection_of_face[3], detection_of_face[0]), (detection_of_face[1], detection_of_face[2]), (0, 255, 255), 2)
    
    else:
        cv2.putText(frame, 'Multiple faces detected', (50, 50), cv2.FONT_HERSHEY_SIMPLEX , 1, (0, 255, 255), 2, cv2.LINE_4) 



    # Display the frame
    cv2.imshow('Webcam', frame)

    # Wait for the user to press 'c' to capture an image
    key = cv2.waitKey(1) & 0xFF
    if key == ord('c'):
        # Save the captured image (you can change the filename as needed)
        cv2.imwrite('captured_image.jpg', frame)
        print("Image captured!")

    # Break the loop if the user presses 'q'
    elif key == ord('q'):
        break

# Release the webcam and close the OpenCV window
cap.release()
cv2.destroyAllWindows()
# Out:
# A face is located at pixel location Top: 225, Left: 296, Bottom: 354, Right: 425
# [225, 425, 354, 296]
# A face is located at pixel location Top: 219, Left: 287, Bottom: 374, Right: 442
# [219, 442, 374, 287]
# A face is located at pixel location Top: 219, Left: 287, Bottom: 374, Right: 442
# [219, 442, 374, 287]
# A face is located at pixel location Top: 219, Left: 287, Bottom: 374, Right: 442
# [219, 442, 374, 287]
# A face is located at pixel location Top: 225, Left: 296, Bottom: 354, Right: 425
# [225, 425, 354, 296]
# A face is located at pixel location Top: 219, Left: 287, Bottom: 374, Right: 442
# [219, 442, 374, 287]
# A face is located at pixel location Top: 254, Left: 296, Bottom: 383, Right: 425
# [254, 425, 383, 296]
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# A face is located at pixel location Top: 254, Left: 296, Bottom: 383, Right: 425
# [254, 425, 383, 296]
# A face is located at pixel location Top: 254, Left: 296, Bottom: 383, Right: 425
# [254, 425, 383, 296]
# A face is located at pixel location Top: 254, Left: 296, Bottom: 383, Right: 425
# [254, 425, 383, 296]
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# Multiple faces detected
# None
# A face is located at pixel location Top: 26, Left: 56, Bottom: 116, Right: 145
# [26, 145, 116, 56]
# None
# A face is located at pixel location Top: 310, Left: 487, Bottom: 353, Right: 530
# [310, 530, 353, 487]
# A face is located at pixel location Top: 310, Left: 491, Bottom: 353, Right: 535
# [310, 535, 353, 491]
# Multiple faces detected
# None
# A face is located at pixel location Top: 7, Left: 195, Bottom: 96, Right: 285
# [7, 285, 96, 195]
# None
# A face is located at pixel location Top: 8, Left: 223, Bottom: 116, Right: 330
# [8, 330, 116, 223]
# None
# A face is located at pixel location Top: 314, Left: 564, Bottom: 358, Right: 607
# [314, 607, 358, 564]
# None
# A face is located at pixel location Top: 96, Left: 282, Bottom: 225, Right: 411
# [96, 411, 225, 282]
# A face is located at pixel location Top: 96, Left: 282, Bottom: 225, Right: 411
# [96, 411, 225, 282]
# A face is located at pixel location Top: 104, Left: 294, Bottom: 211, Right: 402
# [104, 402, 211, 294]
# A face is located at pixel location Top: 96, Left: 296, Bottom: 225, Right: 425
# [96, 425, 225, 296]
# A face is located at pixel location Top: 104, Left: 306, Bottom: 211, Right: 414
# [104, 414, 211, 306]
# None
# A face is located at pixel location Top: 68, Left: 294, Bottom: 175, Right: 402
# [68, 402, 175, 294]
# A face is located at pixel location Top: 295, Left: 530, Bottom: 338, Right: 573
# [295, 573, 338, 530]
# A face is located at pixel location Top: 295, Left: 520, Bottom: 338, Right: 564
# [295, 564, 338, 520]
# A face is located at pixel location Top: 290, Left: 516, Bottom: 334, Right: 559
# [290, 559, 334, 516]
# A face is located at pixel location Top: 290, Left: 516, Bottom: 334, Right: 559
# [290, 559, 334, 516]
# None
# None
# None
# None
# None
# None
# A face is located at pixel location Top: 0, Left: 294, Bottom: 104, Right: 402
# [0, 402, 104, 294]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# A face is located at pixel location Top: 310, Left: 568, Bottom: 353, Right: 612
# [310, 612, 353, 568]
# A face is located at pixel location Top: 300, Left: 549, Bottom: 343, Right: 592
# [300, 592, 343, 549]
# A face is located at pixel location Top: 295, Left: 516, Bottom: 338, Right: 559
# [295, 559, 338, 516]
# A face is located at pixel location Top: 295, Left: 491, Bottom: 338, Right: 535
# [295, 535, 338, 491]
# A face is located at pixel location Top: 300, Left: 482, Bottom: 343, Right: 525
# [300, 525, 343, 482]
# A face is located at pixel location Top: 300, Left: 482, Bottom: 343, Right: 525
# [300, 525, 343, 482]
# A face is located at pixel location Top: 295, Left: 487, Bottom: 338, Right: 530
# [295, 530, 338, 487]
# A face is located at pixel location Top: 295, Left: 491, Bottom: 338, Right: 535
# [295, 535, 338, 491]
# A face is located at pixel location Top: 295, Left: 501, Bottom: 338, Right: 544
# [295, 544, 338, 501]
# A face is located at pixel location Top: 300, Left: 516, Bottom: 343, Right: 559
# [300, 559, 343, 516]
# A face is located at pixel location Top: 300, Left: 520, Bottom: 343, Right: 564
# [300, 564, 343, 520]
# A face is located at pixel location Top: 300, Left: 516, Bottom: 343, Right: 559
# [300, 559, 343, 516]
# A face is located at pixel location Top: 295, Left: 496, Bottom: 338, Right: 540
# [295, 540, 338, 496]
# A face is located at pixel location Top: 295, Left: 491, Bottom: 338, Right: 535
# [295, 535, 338, 491]
# A face is located at pixel location Top: 295, Left: 487, Bottom: 338, Right: 530
# [295, 530, 338, 487]
# A face is located at pixel location Top: 295, Left: 487, Bottom: 338, Right: 530
# [295, 530, 338, 487]
# A face is located at pixel location Top: 295, Left: 491, Bottom: 338, Right: 535
# [295, 535, 338, 491]
# A face is located at pixel location Top: 300, Left: 506, Bottom: 343, Right: 549
# [300, 549, 343, 506]
# A face is located at pixel location Top: 300, Left: 525, Bottom: 343, Right: 568
# [300, 568, 343, 525]
# A face is located at pixel location Top: 300, Left: 540, Bottom: 343, Right: 583
# [300, 583, 343, 540]
# A face is located at pixel location Top: 305, Left: 549, Bottom: 348, Right: 592
# [305, 592, 348, 549]
# A face is located at pixel location Top: 310, Left: 554, Bottom: 353, Right: 597
# [310, 597, 353, 554]
# A face is located at pixel location Top: 310, Left: 559, Bottom: 353, Right: 602
# [310, 602, 353, 559]
# A face is located at pixel location Top: 310, Left: 559, Bottom: 353, Right: 602
# [310, 602, 353, 559]
# A face is located at pixel location Top: 310, Left: 559, Bottom: 353, Right: 602
# [310, 602, 353, 559]
# A face is located at pixel location Top: 310, Left: 554, Bottom: 353, Right: 597
# [310, 597, 353, 554]
# A face is located at pixel location Top: 310, Left: 559, Bottom: 353, Right: 602
# [310, 602, 353, 559]
# None
# A face is located at pixel location Top: 47, Left: 13, Bottom: 121, Right: 88
# [47, 88, 121, 13]
# A face is located at pixel location Top: 47, Left: 30, Bottom: 121, Right: 104
# [47, 104, 121, 30]
# A face is located at pixel location Top: 46, Left: 56, Bottom: 136, Right: 145
# [46, 145, 136, 56]
# A face is located at pixel location Top: 46, Left: 66, Bottom: 136, Right: 155
# [46, 155, 136, 66]
# A face is located at pixel location Top: 314, Left: 549, Bottom: 358, Right: 592
# [314, 592, 358, 549]
# A face is located at pixel location Top: 310, Left: 544, Bottom: 353, Right: 588
# [310, 588, 353, 544]
# A face is located at pixel location Top: 310, Left: 544, Bottom: 353, Right: 588
# [310, 588, 353, 544]
# A face is located at pixel location Top: 305, Left: 540, Bottom: 348, Right: 583
# [305, 583, 348, 540]
# A face is located at pixel location Top: 305, Left: 535, Bottom: 348, Right: 578
# [305, 578, 348, 535]
# A face is located at pixel location Top: 305, Left: 535, Bottom: 348, Right: 578
# [305, 578, 348, 535]
# Multiple faces detected
# None
# Multiple faces detected
# None
# A face is located at pixel location Top: 305, Left: 535, Bottom: 348, Right: 578
# [305, 578, 348, 535]
# A face is located at pixel location Top: 300, Left: 530, Bottom: 343, Right: 573
# [300, 573, 343, 530]
# A face is located at pixel location Top: 300, Left: 525, Bottom: 343, Right: 568
# [300, 568, 343, 525]
# A face is located at pixel location Top: 300, Left: 520, Bottom: 343, Right: 564
# [300, 564, 343, 520]
# None
# Multiple faces detected
# None
# A face is located at pixel location Top: 36, Left: 16, Bottom: 126, Right: 106
# [36, 106, 126, 16]
# A face is located at pixel location Top: 201, Left: 489, Bottom: 387, Right: 640
# [201, 640, 387, 489]
# None
# None
# None
# None
# None
# A face is located at pixel location Top: 0, Left: 8, Bottom: 104, Right: 115
# [0, 115, 104, 8]
# A face is located at pixel location Top: 7, Left: 66, Bottom: 96, Right: 155
# [7, 155, 96, 66]
# A face is located at pixel location Top: 139, Left: 386, Bottom: 325, Right: 572
# [139, 572, 325, 386]
# None
# A face is located at pixel location Top: 167, Left: 356, Bottom: 322, Right: 511
# [167, 511, 322, 356]
# A face is located at pixel location Top: 139, Left: 304, Bottom: 325, Right: 489
# [139, 489, 325, 304]
# Multiple faces detected
# None
# A face is located at pixel location Top: 167, Left: 270, Bottom: 322, Right: 425
# [167, 425, 322, 270]
# A face is located at pixel location Top: 167, Left: 253, Bottom: 322, Right: 408
# [167, 408, 322, 253]
# A face is located at pixel location Top: 167, Left: 236, Bottom: 322, Right: 390
# [167, 390, 322, 236]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 218, Bottom: 339, Right: 373
# [184, 373, 339, 218]
# A face is located at pixel location Top: 184, Left: 218, Bottom: 339, Right: 373
# [184, 373, 339, 218]
# A face is located at pixel location Top: 184, Left: 218, Bottom: 339, Right: 373
# [184, 373, 339, 218]
# Multiple faces detected
# None
# Multiple faces detected
# None
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# Multiple faces detected
# None
# Multiple faces detected
# None
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 218, Bottom: 339, Right: 373
# [184, 373, 339, 218]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 218, Bottom: 339, Right: 373
# [184, 373, 339, 218]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
# A face is located at pixel location Top: 184, Left: 236, Bottom: 339, Right: 390
# [184, 390, 339, 236]
